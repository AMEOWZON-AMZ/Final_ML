# %%
# !python -u scripts/music_infer.py
# Out:
# ⬇ Downloading from S3...
# ✅ vocal  from s3://amz-bgm/meow/stem/chaos/vocal.mp3
# ✅ bgm    from s3://amz-bgm/meow/stem/chaos/background.mp3
# ✅ enroll from s3://amz-bgm/meow/enroll/74e8edac-f031-70a5-9bef-f388ea61c0a8/enroll.wav
# 🎧 Converting inputs to wav (mono)...
# 🧾 CMD: ffmpeg -y -i /mnt/custom-file-systems/efs/fs-061960ade5d398601_fsap-009d5c1abe414adf7/meow-seedvc/cache/work/vocal_input.mp3 -ar 44100 -ac 1 -c:a pcm_s16le /mnt/custom-file-systems/efs/fs-061960ade5d398601_fsap-009d5c1abe414adf7/meow-seedvc/cache/work/vocal.tmp.wav
# ffmpeg version 7.0.2-static https://johnvansickle.com/ffmpeg/  Copyright (c) 2000-2024 the FFmpeg developers
#   built with gcc 8 (Debian 8.3.0-6)
# ...

# %%
# !python scripts/run_music_batch.py
# Out:
# Traceback (most recent call last):
#   File "/mnt/custom-file-systems/efs/fs-061960ade5d398601_fsap-009d5c1abe414adf7/meow-seedvc/scripts/run_music_batch.py", line 14, in <module>
#     DT = os.environ["DT"]  # e.g. 2026-02-12
#          ~~~~~~~~~~^^^^^^
#   File "<frozen os>", line 714, in __getitem__
# KeyError: 'DT'

# %%
# !DT=2026-02-12 USER_POD_BASE="http://k8s-userserv-userserv-faeaf14223-576848475.ap-northeast-2.elb.amazonaws.com" python scripts/run_music_batch.py
# Out:
# [SKIP] user_id=b4589ddc-a001-7001-77aa-c2c3f3fd6a98 state=NO_DATA reason=STATE_IN_SKIP_STATES
# [SKIP] user_id=c478cd4c-5071-7060-2991-cc9b3bb59dff state=NO_DATA reason=STATE_IN_SKIP_STATES
# [SKIP] user_id=74e8edac-f031-70a5-9bef-f388ea61c0a8 state=NO_DATA reason=STATE_IN_SKIP_STATES
# {"dt": "2026-02-12", "total_items": 3, "skipped": 3, "success": 0, "failed": 0}
